# %%
import pandas as pd
import pickle

# %%
df=pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
#batting team
#bowling team
#city
#current score
#ball left
#wickets left
#current run rate
#runs scored in last 5 overs
# total 8 columns
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                0
# 1           2    Australia     Pakistan   0.2     0                0
# 2           2    Australia     Pakistan   0.3     0                0
# 3           2    Australia     Pakistan   0.4     0                0
# 4           2    Australia     Pakistan   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 244      1795    Sri Lanka    Australia  39.5     0                0
# 245      1795    Sri Lanka    Australia  39.6     0                0
# 246      1795    Sri Lanka    Australia  39.7     1                0
# 247      1795    Sri Lanka    Australia  40.1     0                0
# 248      1795    Sri Lanka    Australia  40.2     0     SS Pathirana
#
#          city                                    venue
# 0    Brisbane   Brisbane Cricket Ground, Woolloongabba
# ...

# %%
df.isnull().sum()
# Out:
# match_id                0
# batting_team            0
# bowling_team            0
# ball                    0
# runs                    0
# player_dismissed        0
# city                55774
# venue                   0
# dtype: int64

# %%
df['city'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 244     True
# 245     True
# 246     True
# 247     True
# 248     True
# Name: city, Length: 310644, dtype: bool

# %%
df[df['city'].isnull()]
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed city  \
# 0           3    Australia     Pakistan   0.1     3                0  NaN
# 1           3    Australia     Pakistan   0.2     0                0  NaN
# 2           3    Australia     Pakistan   0.3     1                0  NaN
# 3           3    Australia     Pakistan   0.4     1                0  NaN
# 4           3    Australia     Pakistan   0.5     0                0  NaN
# ..        ...          ...          ...   ...   ...              ...  ...
# 244      1795    Sri Lanka    Australia  39.5     0                0  NaN
# 245      1795    Sri Lanka    Australia  39.6     0                0  NaN
# 246      1795    Sri Lanka    Australia  39.7     1                0  NaN
# 247      1795    Sri Lanka    Australia  40.1     0                0  NaN
# 248      1795    Sri Lanka    Australia  40.2     0     SS Pathirana  NaN
#
#                                        venue
# ...

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Rangiri Dambulla International Stadium     9450
# Sydney Cricket Ground                      9287
# Melbourne Cricket Ground                   7778
# Adelaide Oval                              7166
# Dubai International Cricket Stadium        6314
# Pallekele International Cricket Stadium    5945
# Sharjah Cricket Stadium                    4291
# Harare Sports Club                         1538
# Chittagong Divisional Stadium               900
# Multan Cricket Stadium                      883
# Rawalpindi Cricket Stadium                  617
# Perth Stadium                               526
# Dubai Sports City Cricket Stadium           518
# Sharjah Cricket Association Stadium         303
# Queenstown Events Centre                    258
# Name: venue, dtype: int64

# %%
import numpy as np

# %%
cities=np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['venue'].str.split().apply(lambda x:x[0])
# Out:
# 0       Brisbane
# 1       Brisbane
# 2       Brisbane
# 3       Brisbane
# 4       Brisbane
#          ...
# 244    Pallekele
# 245    Pallekele
# 246    Pallekele
# 247    Pallekele
# 248    Pallekele
# Name: venue, Length: 310644, dtype: object

# %%
df['city']=cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                0
# 1           2    Australia     Pakistan   0.2     0                0
# 2           2    Australia     Pakistan   0.3     0                0
# 3           2    Australia     Pakistan   0.4     0                0
# 4           2    Australia     Pakistan   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 244      1795    Sri Lanka    Australia  39.5     0                0
# 245      1795    Sri Lanka    Australia  39.6     0                0
# 246      1795    Sri Lanka    Australia  39.7     1                0
# 247      1795    Sri Lanka    Australia  40.1     0                0
# 248      1795    Sri Lanka    Australia  40.2     0     SS Pathirana
#
#           city
# 0     Brisbane
# 1     Brisbane
# 2     Brisbane
# 3     Brisbane
# 4     Brisbane
# ..         ...
# 244  Pallekele
# ...

# %%
eligible_cities = df['city'].value_counts().index.tolist()

# %%
df=df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                0
# 1           2    Australia     Pakistan   0.2     0                0
# 2           2    Australia     Pakistan   0.3     0                0
# 3           2    Australia     Pakistan   0.4     0                0
# 4           2    Australia     Pakistan   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 244      1795    Sri Lanka    Australia  39.5     0                0
# 245      1795    Sri Lanka    Australia  39.6     0                0
# 246      1795    Sri Lanka    Australia  39.7     1                0
# 247      1795    Sri Lanka    Australia  40.1     0                0
# 248      1795    Sri Lanka    Australia  40.2     0     SS Pathirana
#
#           city
# 0     Brisbane
# 1     Brisbane
# 2     Brisbane
# 3     Brisbane
# 4     Brisbane
# ..         ...
# 244  Pallekele
# ...

# %%
print(df['runs'].dtype)
# Out:
# int64

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')  # 'coerce' will handle non-numeric values by converting them to NaN

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                0
# 1           2    Australia     Pakistan   0.2     0                0
# 2           2    Australia     Pakistan   0.3     0                0
# 3           2    Australia     Pakistan   0.4     0                0
# 4           2    Australia     Pakistan   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 244      1795    Sri Lanka    Australia  39.5     0                0
# 245      1795    Sri Lanka    Australia  39.6     0                0
# 246      1795    Sri Lanka    Australia  39.7     1                0
# 247      1795    Sri Lanka    Australia  40.1     0                0
# 248      1795    Sri Lanka    Australia  40.2     0     SS Pathirana
#
#           city  current_score
# 0     Brisbane              0
# 1     Brisbane              0
# 2     Brisbane              0
# ...

# %%
#focus on balls and wickets left
#separating overs and balls
df['over']=df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no']=df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                0
# 1           2    Australia     Pakistan   0.2     0                0
# 2           2    Australia     Pakistan   0.3     0                0
# 3           2    Australia     Pakistan   0.4     0                0
# 4           2    Australia     Pakistan   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 244      1795    Sri Lanka    Australia  39.5     0                0
# 245      1795    Sri Lanka    Australia  39.6     0                0
# 246      1795    Sri Lanka    Australia  39.7     1                0
# 247      1795    Sri Lanka    Australia  40.1     0                0
# 248      1795    Sri Lanka    Australia  40.2     0     SS Pathirana
#
#           city  current_score over ball_no
# 0     Brisbane              0    0       1
# 1     Brisbane              0    0       2
# ...

# %%
df['balls_bowled']=(df['over'].astype('int')*6)+df['ball_no'].astype('int')

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                0
# 1           2    Australia     Pakistan   0.2     0                0
# 2           2    Australia     Pakistan   0.3     0                0
# 3           2    Australia     Pakistan   0.4     0                0
# 4           2    Australia     Pakistan   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 244      1795    Sri Lanka    Australia  39.5     0                0
# 245      1795    Sri Lanka    Australia  39.6     0                0
# 246      1795    Sri Lanka    Australia  39.7     1                0
# 247      1795    Sri Lanka    Australia  40.1     0                0
# 248      1795    Sri Lanka    Australia  40.2     0     SS Pathirana
#
#           city  current_score over ball_no  balls_bowled
# 0     Brisbane              0    0       1             1
# ...

# %%
df['balls_left']=300- df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
print(df[df['player_dismissed'] == '0'])
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                0
# 1           2    Australia     Pakistan   0.2     0                0
# 2           2    Australia     Pakistan   0.3     0                0
# 3           2    Australia     Pakistan   0.4     0                0
# 4           2    Australia     Pakistan   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 243      1795    Sri Lanka    Australia  39.4     5                0
# 244      1795    Sri Lanka    Australia  39.5     0                0
# 245      1795    Sri Lanka    Australia  39.6     0                0
# 246      1795    Sri Lanka    Australia  39.7     1                0
# 247      1795    Sri Lanka    Australia  40.1     0                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0     Brisbane              0    0       1             1         299
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)

# Calculate cumulative sum of dismissals within each match
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# Calculate wickets left
df['wickets_left'] = 10 - df['player_dismissed']

# Ensure 'wickets_left' doesn't go below 0
df['wickets_left'] = df['wickets_left'].clip(lower=0)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                 0
# 1           2    Australia     Pakistan   0.2     0                 0
# 2           2    Australia     Pakistan   0.3     0                 0
# 3           2    Australia     Pakistan   0.4     0                 0
# 4           2    Australia     Pakistan   0.5     1                 0
# ..        ...          ...          ...   ...   ...               ...
# 244      1795    Sri Lanka    Australia  39.5     0                 9
# 245      1795    Sri Lanka    Australia  39.6     0                 9
# 246      1795    Sri Lanka    Australia  39.7     1                 9
# 247      1795    Sri Lanka    Australia  40.1     0                 9
# 248      1795    Sri Lanka    Australia  40.2     0                10
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                 0
# 1           2    Australia     Pakistan   0.2     0                 0
# 2           2    Australia     Pakistan   0.3     0                 0
# 3           2    Australia     Pakistan   0.4     0                 0
# 4           2    Australia     Pakistan   0.5     1                 0
# ..        ...          ...          ...   ...   ...               ...
# 244      1795    Sri Lanka    Australia  39.5     0                 9
# 245      1795    Sri Lanka    Australia  39.6     0                 9
# 246      1795    Sri Lanka    Australia  39.7     1                 9
# 247      1795    Sri Lanka    Australia  40.1     0                 9
# 248      1795    Sri Lanka    Australia  40.2     0                10
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 9537     Bangladesh        India  Birmingham            244          17
# 175425  New Zealand    Australia      Nagpur            100         155
#
#         wickets_left       crr  last_five  runs_x
# 9537               3  5.173145       26.0     264
# 175425             4  4.137931       22.0     206

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#         batting_team  bowling_team            city  current_score  balls_left  \
# 294666     Sri Lanka      Pakistan      Hambantota            133         170
# 79439   South Africa         India          Mumbai             75         182
# 217985         India     Sri Lanka          Mirpur             31         251
# 63343      Australia  South Africa    Bloemfontein            222          58
# 286810       England     Australia          Hobart            131         168
# ...              ...           ...             ...            ...         ...
# 178199   Netherlands    Bangladesh      Chittagong             17         260
# 40143        England    Bangladesh         Cardiff            314          38
# 307337     Australia  South Africa  Port Elizabeth            103         146
# 86400       Pakistan         India         Karachi             62         234
# 231998     Australia     Sri Lanka       Melbourne             23         266
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
# !pip install xgboost

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9902711895212609
# 2.5371206764439034

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '2.1.0'
